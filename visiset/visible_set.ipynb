# %% [markdown]
# # VisiSet
#
# A set-like collection backed by a numpy structured array with two columns:
# `hash` (`int64`) and `value` (`object`).
#
# Jupyter renders instances as numpy-style tables showing the internal hash/value pairs.

# %%
s = set()
s
# Out:
# set()

# %%
s.add('c')
s
# Out:
# {'c'}

# %%
from visiset import VisiSet

# %% [markdown]
# ## Examples

# %%
VisiSet([0, 1, -1, 2, -2])
# Out:
# VisiSet({0, 1, 2, -1, -2})

# %%
VisiSet([0, 1, 7, -2, -1])
# Out:
# VisiSet({0, 1, -1, -2, 7})

# %%
VisiSet(['açaí', 'banana', 'carambola', 'bananA'], hash_base=2)
# Out:
# VisiSet({'carambola', 'açaí', 'banana', 'bananA'})

# %%
VisiSet([3.14, True, (1, 2), frozenset({10, 20}), 'Lua'])
# Out:
# VisiSet({True, frozenset({10, 20}), 3.14, (1, 2), 'Lua'})

# %% [markdown]
# ### Set interface

# %%
vs = VisiSet(['a', 'b', 'c'])
vs.add('d')
vs.add('b')  # duplicate — ignored
vs
# Out:
# VisiSet({'a', 'b', 'c', 'd'})

# %%
'b' in vs, 'z' in vs
# Out:
# (True, False)

# %%
len(vs)
# Out:
# 4

# %%
list(vs)
# Out:
# ['a', 'b', 'c', 'd']

# %% [markdown]
# ### Plain text repr

# %%
print(repr(vs))
# Out:
# VisiSet({'a', 'b', 'c', 'd'})

# %% [markdown]
# ## Demo with strings

# %%
v = VisiSet()
v
# Out:
# VisiSet({})

# %%
v.add('Alice')
v
# Out:
# VisiSet({'Alice'})

# %%
v.add('Bob')
v
# Out:
# VisiSet({'Alice', 'Bob'})

# %%
v.add('Carla')
v
# Out:
# VisiSet({'Carla', 'Alice', 'Bob'})

# %%
v.add('Diego')
v
# Out:
# VisiSet({'Carla', 'Alice', 'Bob', 'Diego'})

# %%
v.add('Elise')
v
# Out:
# VisiSet({'Carla', 'Alice', 'Bob', 'Diego', 'Elise'})

# %%
v.add('Fred')
v
# Out:
# VisiSet({'Bob', 'Fred', 'Carla', 'Alice', 'Diego', 'Elise'})

# %%
v.union('Gina Homer Ian Jane'.split())
# Out:
# VisiSet({'Ian', 'Bob', 'Jane', 'Fred', 'Gina', 'Carla', 'Alice', 'Diego', 'Elise', 'Homer'})

# %%
v.add('Zeta')
v
# Out:
# VisiSet({'Zeta', 'Bob', 'Fred', 'Carla', 'Alice', 'Diego', 'Elise'})

# %% [markdown]
# ## Demo with numbers

# %%
v = VisiSet([10, 20, 30, 40])
v
# Out:
# VisiSet({40, 10, 20, 30})

# %%
v.add(50)
v
# Out:
# VisiSet({40, 10, 50, 20, 30})

# %%
v.add(2)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30})

# %%
v.add(2.0)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30})

# %%
v.add(15)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30, 15})

# %%
v.add(31)
v
# Out:
# VisiSet({31, 50, 2, 20, 40, 10, 30, 15})

# %%
v.add(47)
v
# Out:
# VisiSet({31, 47, 50, 2, 20, 40, 10, 30, 15})

# %%
v.add(63)
v
# Out:
# VisiSet({31, 47, 50, 2, 20, 63, 40, 10, 30, 15})

# %%
v.add(79)
v
# Out:
# VisiSet({63, 2, 40, 10, 47, 15, 79, 50, 20, 30, 31})
