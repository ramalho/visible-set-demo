# %% [markdown]
# # VisiSet
#
# A set-like collection backed by a numpy structured array with two columns:
# `hash` (`int64`) and `value` (`object`).
#
# Jupyter renders instances as numpy-style tables showing the internal hash/value pairs.

# %%
from visiset import VisiSet

# %% [markdown]
# ## Examples

# %%
VisiSet([0, 1, -1, 2, -2])
# Out:
# VisiSet({0, 1, 2, -1, -2})

# %%
VisiSet([0, 1, 7, -2, -1])
# Out:
# VisiSet({0, 1, -1, -2, 7})

# %%
VisiSet(['açaí', 'banana', 'carambola', 'bananA'], fmt_base=2)
# Out:
# VisiSet({'açaí', 'carambola', 'banana', 'bananA'})

# %%
VisiSet([3.14, True, (1, 2), frozenset({10, 20}), 'Lua'])
# Out:
# VisiSet({True, frozenset({10, 20}), 3.14, (1, 2), 'Lua'})

# %% [markdown]
# ### Set interface

# %%
v = VisiSet(['a', 'b', 'c'])
v.add('d')
v.add('b')  # duplicate — ignored
v
# Out:
# VisiSet({'b', 'a', 'c', 'd'})

# %%
'b' in v, 'z' in v
# Out:
# (True, False)

# %%
len(v)
# Out:
# 4

# %%
list(v)
# Out:
# ['b', 'a', 'c', 'd']

# %% [markdown]
# ### Plain text repr

# %%
print(repr(v))
# Out:
# VisiSet({'b', 'a', 'c', 'd'})

# %% [markdown]
# ## Demo with strings

# %%
v = VisiSet()
v
# Out:
# VisiSet({})

# %%
v.add('Alice')
v
# Out:
# VisiSet({'Alice'})

# %%
v.add('Bob')
v
# Out:
# VisiSet({'Bob', 'Alice'})

# %%
v.add('Carla')
v
# Out:
# VisiSet({'Bob', 'Carla', 'Alice'})

# %%
v.add('Diego')
v
# Out:
# VisiSet({'Bob', 'Carla', 'Alice', 'Diego'})

# %%
v.add('Elise')
v
# Out:
# VisiSet({'Bob', 'Carla', 'Alice', 'Diego', 'Elise'})

# %%
v.add('Fred')
v
# Out:
# VisiSet({'Carla', 'Elise', 'Fred', 'Bob', 'Diego', 'Alice'})

# %%
v.union('Gina Homer Ian Jane'.split())
# Out:
# VisiSet({'Carla', 'Elise', 'Ian', 'Homer', 'Fred', 'Bob', 'Diego', 'Alice', 'Gina', 'Jane'})

# %%
v.add('Zeta')
v
# Out:
# VisiSet({'Carla', 'Elise', 'Fred', 'Bob', 'Diego', 'Alice', 'Zeta'})

# %% [markdown]
# ## Demo with numbers

# %%
v = VisiSet([10, 20, 30, 40])
v
# Out:
# VisiSet({40, 10, 20, 30})

# %%
v.add(50)
v
# Out:
# VisiSet({40, 10, 50, 20, 30})

# %%
v.add(2)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30})

# %%
v.add(2.0)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30})

# %%
v.add(15)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30, 15})

# %%
v.add(31)
v
# Out:
# VisiSet({31, 50, 2, 20, 40, 10, 30, 15})

# %%
v.add(47)
v
# Out:
# VisiSet({31, 47, 50, 2, 20, 40, 10, 30, 15})

# %%
v.add(63)
v
# Out:
# VisiSet({31, 47, 50, 2, 20, 63, 40, 10, 30, 15})

# %%
v.add(79)
v
# Out:
# VisiSet({63, 2, 40, 10, 47, 15, 79, 50, 20, 30, 31})
