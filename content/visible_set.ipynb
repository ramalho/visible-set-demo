# %% [markdown]
# # VisiSet
#
# A set-like collection backed by a numpy structured array with two columns:
# `hash` (`int64`) and `value` (`object`).
#
# Jupyter renders instances as numpy-style tables showing the internal hash/value pairs.

# %% [markdown]
# ## Examples

# %%
from visiset import VisiSet

VisiSet([0, 1, -1, 2, -2])
# Out:
# VisiSet({0, 1, 2, -1, -2})

# %%
VisiSet([0, 1, 7, -2, -1])
# Out:
# VisiSet({0, 1, -1, -2, 7})

# %%
VisiSet(['açaí', 'banana', 'carambola', 'bananA'], fmt_base=2)
# Out:
# VisiSet({'açaí', 'bananA', 'carambola', 'banana'})

# %%
VisiSet([3.14, True, (1, 2), frozenset({10, 20}), 'Lua'])
# Out:
# VisiSet({True, frozenset({10, 20}), 3.14, (1, 2), 'Lua'})

# %% [markdown]
# ### Set interface

# %%
v = VisiSet(['a', 'b', 'c'])
v.add('d')
v.add('b')  # duplicate — ignored
v
# Out:
# VisiSet({'b', 'd', 'a', 'c'})

# %%
'b' in v, 'z' in v
# Out:
# (True, False)

# %%
len(v)
# Out:
# 4

# %%
list(v)
# Out:
# ['b', 'd', 'a', 'c']

# %% [markdown]
# ### Plain text repr

# %%
print(repr(v))
# Out:
# VisiSet({'b', 'd', 'a', 'c'})

# %% [markdown]
# ## Demo with strings

# %%
v = VisiSet()
v
# Out:
# VisiSet({})

# %%
v.add('Alice')
v
# Out:
# VisiSet({'Alice'})

# %%
v.add('Bob')
v
# Out:
# VisiSet({'Alice', 'Bob'})

# %%
v.add('Carla')
v
# Out:
# VisiSet({'Alice', 'Carla', 'Bob'})

# %%
v.add('Diego')
v
# Out:
# VisiSet({'Alice', 'Carla', 'Bob', 'Diego'})

# %%
v.add('Elise')
v
# Out:
# VisiSet({'Alice', 'Carla', 'Elise', 'Bob', 'Diego'})

# %%
v.add('Fred')
v
# Out:
# VisiSet({'Alice', 'Carla', 'Fred', 'Bob', 'Diego', 'Elise'})

# %%
v.union('Gina Homer Ian Jane'.split())
# Out:
# VisiSet({'Alice', 'Homer', 'Carla', 'Fred', 'Bob', 'Diego', 'Gina', 'Jane', 'Ian', 'Elise'})

# %%
v.add('Zeta')
v
# Out:
# VisiSet({'Alice', 'Carla', 'Fred', 'Bob', 'Diego', 'Zeta', 'Elise'})

# %% [markdown]
# ## Demo with numbers

# %%
v = VisiSet([10, 20, 30, 40])
v
# Out:
# VisiSet({40, 10, 20, 30})

# %%
v.add(50)
v
# Out:
# VisiSet({40, 10, 50, 20, 30})

# %%
v.add(2)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30})

# %%
v.add(2.0)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30})

# %%
v.add(15)
v
# Out:
# VisiSet({50, 2, 20, 40, 10, 30, 15})

# %%
v.add(31)
v
# Out:
# VisiSet({31, 50, 2, 20, 40, 10, 30, 15})

# %%
v.add(47)
v
# Out:
# VisiSet({31, 47, 50, 2, 20, 40, 10, 30, 15})

# %%
v.add(63)
v
# Out:
# VisiSet({31, 47, 50, 2, 20, 63, 40, 10, 30, 15})

# %%
v.add(79)
v
# Out:
# VisiSet({63, 2, 40, 10, 47, 15, 79, 50, 20, 30, 31})
